# %% [markdown]
# # RecursiveCharacterTextSplitter হলো LangChain-এর সবচেয়ে গুরুত্বপূর্ণ text splitting technique—বিশেষ করে RAG (Retrieval Augmented Generation), chatbot, embedding pipeline-এ।
#
# এটা naive splitter না; এটা hierarchical splitting strategy ব্যবহার করে যাতে context যতটা সম্ভব intact থাকে।

# %%
# !pip install -q langchain langchain-community pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
pdf_path = "data.pdf"

# %%
loader = PyPDFLoader(pdf_path)
docs = loader.load()

# %%
print("Total pages:", len(docs))
# Out:
# Total pages: 399

# %%
print(docs[0].page_content[:1000])
# Out:
# Supreme Court Online Bulletin
# (Law Report)
# 2023
#
#
#
# Editors
# Justice Sheikh Hassan Arif
# Justice Md. Zakir Hossain
#
#
#
# Citation:
# 18 SCOB [2023] AD
# 18 SCOB [2023] HCD
#
#
# Supreme Court of Bangladesh

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=150,
    separators=["\n\n", "\n", ".", " ", ""]
)

# %%
chunks = splitter.split_documents(docs)

# %%
print("Total chunks:", len(chunks))
# Out:
# Total chunks: 1600

# %%
print(chunks[0].metadata)
# Out:
# {'producer': 'doPDF Ver 9.6 Build 246', 'creator': 'Adobe Acrobat 6.0', 'creationdate': '2023-09-04T11:04:55+06:00', 'moddate': '2023-09-04T11:04:55+06:00', 'source': 'data.pdf', 'total_pages': 399, 'page': 0, 'page_label': '1'}

# %%
for i in range(3):
    print(f"\n--- Chunk {i+1} ---")
    print(chunks[i].page_content[:300])
    print("Metadata:", chunks[i].metadata)
# Out:
# --- Chunk 1 ---
# Supreme Court Online Bulletin
# (Law Report)
# 2023
#
#
#
# Editors
# Justice Sheikh Hassan Arif
# Justice Md. Zakir Hossain
#
#
#
# Citation:
# 18 SCOB [2023] AD
# 18 SCOB [2023] HCD
#
#
# Supreme Court of Bangladesh
# Metadata: {'producer': 'doPDF Ver 9.6 Build 246', 'creator': 'Adobe Acrobat 6.0', 'creationdate': '2023-09-04T11:04:55+06:00', 'moddate': '2023-09-04T11:04:55+06:00', 'source': 'data.pdf', 'total_pages': 399, 'page': 0, 'page_label': '1'}
#
# --- Chunk 2 ---
# Published by:
#
# Md. Golam Rabbani
# Registrar General
# Supreme Court of Bangladesh
#
# Research Coordinators:
# Mohammad Saifur Rahman
# Registrar
# Appellate Division
#
# SK. Md. Aminul Islam
# Additional Registrar
# Appellate Division
#
# Md. Muajjem Hussain
# Special Officer
# High Court Division
#
#
# ...
